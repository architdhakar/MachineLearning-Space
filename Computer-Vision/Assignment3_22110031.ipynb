# %% [markdown]
# This is submssion template for the assignment 3, Panaroma Stitching.
#
# Refer https://github.com/shash29-dev/ES666-Assignment3 to access the assignment.
#
# A `readme.md` file is provided in the repository with instructions.
#
# If you face any issues or have queries, try opening a issue on github itself. All queries will be addressed through github issues only.

# %%
# %cd /content
# !git clone https://github.com/architdhakar/ES666-Assignment3  # Change with your Fork
# %cd ES666-Assignment3
# !python main.py

# Want to create backup in your drive?
# from google.colab import drive
# drive.mount('/content/drive')
# !cp /content/ES666-Assignment3 /content/drive/MyDrive/ES666_Assignment3  # This Path should Exist In your drive!
# Out:
# /content
# Cloning into 'ES666-Assignment3'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 123 (delta 31), reused 25 (delta 21), pack-reused 82 (from 1)
# Receiving objects: 100% (123/123), 41.71 MiB | 17.23 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /content/ES666-Assignment3
# ****************	Running Awesome Stitcher developed by: JaneDoe  | 0 of 2	********************
# Oh No! My implementation encountered this issue
# 	No module named 'src.JohnDoe'
#
#
#
# ****************	Running Awesome Stitcher developed by: Archit  | 1 of 2	********************
# 		 Processing... Images/I1
# Found 6 Images for stitching
# Best homography found with 172 inliers out of 202 points
# Best homography found with 101 inliers out of 202 points
# Best homography found with 137 inliers out of 160 points
# Best homography found with 159 inliers out of 261 points
# Best homography found with 96 inliers out of 173 points
# []
# Panaroma saved ... @ ./results/Archit_stitcher.png
#
#
#
# 		 Processing... Images/I4
# Found 5 Images for stitching
# Best homography found with 391 inliers out of 420 points
# Best homography found with 616 inliers out of 630 points
# Best homography found with 494 inliers out of 533 points
# Best homography found with 31 inliers out of 50 points
# []
# Panaroma saved ... @ ./results/Archit_stitcher.png
#
#
#
# 		 Processing... Images/I3
# Found 5 Images for stitching
# Best homography found with 118 inliers out of 150 points
# Best homography found with 178 inliers out of 206 points
# Best homography found with 9 inliers out of 44 points
# Best homography found with 5 inliers out of 17 points
# []
# Panaroma saved ... @ ./results/Archit_stitcher.png
#
#
#
# 		 Processing... Images/I6
# Found 5 Images for stitching
# Best homography found with 490 inliers out of 540 points
# Best homography found with 533 inliers out of 572 points
# Best homography found with 416 inliers out of 435 points
# Best homography found with 779 inliers out of 856 points
# []
# Panaroma saved ... @ ./results/Archit_stitcher.png
#
#
#
# 		 Processing... Images/I5
# Found 5 Images for stitching
# Best homography found with 313 inliers out of 369 points
# Best homography found with 596 inliers out of 619 points
# Best homography found with 342 inliers out of 376 points
# Best homography found with 165 inliers out of 189 points
# []
# Panaroma saved ... @ ./results/Archit_stitcher.png
#
#
#
# 		 Processing... Images/I2
# Found 5 Images for stitching
# Best homography found with 276 inliers out of 364 points
# Best homography found with 237 inliers out of 315 points
# Best homography found with 84 inliers out of 178 points
# Best homography found with 7 inliers out of 22 points
# []
# Panaroma saved ... @ ./results/Archit_stitcher.png

# %%
import matplotlib.pyplot as plt
import glob
allims = glob.glob('/content/ES666-Assignment3/results/*/Archit*.png')  # replace JaneDoe by your folder name
for im in allims:
  plt.figure()
  plt.axis('off')
  plt.imshow(plt.imread(im))
